# %% [markdown]
# <a href="https://colab.research.google.com/github/Heleena-pilli/Heleena-pilli/blob/main/Assessment2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import os

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df_1=pd.read_csv('/content/college_1.csv')
df_2=pd.read_csv('/content/college_2.csv')

# %%
df1=pd.DataFrame(df_1)
df2=pd.DataFrame(df_2)

# %%
df1.info()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               84 non-null     object
#  1   python             84 non-null     float64
#  2   mysql              84 non-null     float64
#  3   Previous Geekions  84 non-null     int64
#  4   CodeKata Score     84 non-null     int64
#  5   Department         84 non-null     object
#  6   Rising             84 non-null     int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 4.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    35 non-null     object
#  1   python                  35 non-null     int64
#  2   python_en               35 non-null     int64
# ...

# %%
df1.describe()
df2.describe()
# Out:
#            python   python_en       mysql  computational_thinking  \
# count   35.000000   35.000000   35.000000               35.000000
# mean     8.657143   29.657143   13.657143                2.200000
# std     25.795511   30.582524   22.002597                7.015948
# min     -1.000000   -1.000000   -1.000000               -1.000000
# 25%     -1.000000    0.000000    0.000000                0.000000
# 50%     -1.000000   20.000000    0.000000                0.000000
# 75%     -1.000000   52.000000   24.000000                0.000000
# max    100.000000  100.000000  100.000000               39.000000
#
#        Previous Geekions  CodeKata Score       Rising
# count          35.000000       35.000000    35.000000
# mean         6093.142857     6801.428571   708.285714
# std          3650.436534     3765.281134   836.429687
# min             0.000000        0.000000     0.000000
# 25%          4035.000000     4630.000000     0.000000
# ...

# %%
from pandas.core.internals import concat
df = pd.concat([df1, df2])
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119 entries, 0 to 34
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    119 non-null    object
#  1   python                  119 non-null    float64
#  2   mysql                   119 non-null    float64
#  3   Previous Geekions       119 non-null    int64
#  4   CodeKata Score          119 non-null    int64
#  5   Department              119 non-null    object
#  6   Rising                  119 non-null    int64
#  7   python_en               35 non-null     float64
#  8   computational_thinking  35 non-null     float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 9.3+ KB
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# ...

# %%
df=pd.merge(df1,df2,how='outer')
df.reset_index(drop=True, inplace=True)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py:1208: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   UserWarning,
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119 entries, 0 to 34
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    119 non-null    object
#  1   python                  119 non-null    float64
#  2   mysql                   119 non-null    float64
#  3   Previous Geekions       119 non-null    int64
#  4   CodeKata Score          119 non-null    int64
#  5   Department              119 non-null    object
#  6   Rising                  119 non-null    int64
#  7   python_en               35 non-null     float64
#  8   computational_thinking  35 non-null     float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 9.3+ KB

# %%
df.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN
# 3  Computer Science and Engineering       0        NaN                     NaN
# 4  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
#Exceeded expectations
exceedExp= df['CodeKata Score']>15000
df[exceedExp].to_csv('Exceeded_expectations.csv')

# %%
Exceeded_expectations=pd.read_csv('/content/Exceeded_expectations.csv')
Exceeded_expectations
# Out:
#    Unnamed: 0           Name  python  mysql  Previous Geekions  \
# 0           0      A.Dharani    82.0   20.0              24500
# 1           1    V.JEEVITHA     82.0   20.0              21740
# 2           2    HEMAVATHI.R   100.0  100.0              19680
# 3           0  ASHOK KUMAR K   100.0   31.0              19400
#
#    CodeKata Score                              Department  Rising  python_en  \
# 0           24500        Computer Science and Engineering       0        NaN
# 1           21740        Computer Science and Engineering       0        NaN
# 2           19680        Computer Science and Engineering       0        NaN
# 3           19400  Electronics and Electrical Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     9.0

# %%
#Reached_expectations
reachedExp= (10000<df['CodeKata Score']) & (df['CodeKata Score']<15000)
df[reachedExp].to_csv('Reached_expectations.csv')

# %%
Reached_expectations=pd.read_csv('/content/Exceeded_expectations.csv')
Reached_expectations
# Out:
#    Unnamed: 0           Name  python  mysql  Previous Geekions  \
# 0           0      A.Dharani    82.0   20.0              24500
# 1           1    V.JEEVITHA     82.0   20.0              21740
# 2           2    HEMAVATHI.R   100.0  100.0              19680
# 3           0  ASHOK KUMAR K   100.0   31.0              19400
#
#    CodeKata Score                              Department  Rising  python_en  \
# 0           24500        Computer Science and Engineering       0        NaN
# 1           21740        Computer Science and Engineering       0        NaN
# 2           19680        Computer Science and Engineering       0        NaN
# 3           19400  Electronics and Electrical Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     9.0

# %%
#Needs_Improvement
needImp=(7000<df['CodeKata Score']) & (df['CodeKata Score']<10000)
df[needImp].to_csv('Needs_Improvement.csv')

# %%
Needs_Improvement=pd.read_csv('/content/Needs_Improvement.csv')
Needs_Improvement
# Out:
#     Unnamed: 0                    Name  python  mysql  Previous Geekions  \
# 0            4             Sathammai.S   100.0    8.0               8980
# 1            5            NIVEESHWAR S   100.0    0.0               8200
# 2            6           KALAIARASAN K    85.0   47.0               7750
# 3            7    MOHAMED ZUBAIR AHMED    82.0    4.0               7020
# 4            4               VIINU V P    -1.0   24.0               9150
# 5            5              Poojitha Y     0.0   35.0               7210
# 6            6  Gowtham Chandrasekaran    -1.0    0.0               7250
# 7            7               Gowtham R    -1.0    4.0               8650
# 8            8                shifak N    58.0    0.0               5180
# 9            9                 Balaji     -1.0   20.0               6170
# 10          10                Rushitha    -1.0   62.0               7470
# 11          11    Balaraman Muthupandi    -1.0    0.0               7670
# ...

# %%
#Unsatisfactory
Unsatisfactory= df['CodeKata Score']<7000
df[Unsatisfactory].to_csv('Unsatisfactory.csv')

# %%
Unsatisfactory=pd.read_csv('/content/Unsatisfactory.csv')
Unsatisfactory
# Out:
#     Unnamed: 0             Name  python  mysql  Previous Geekions  \
# 0            8       J.SUGANTHI    27.0  50.00               5860
# 1            9     thamizhpaana    29.0   0.00               5500
# 2           10  Iyappan Samiraj    50.0  24.00               5400
# 3           11     Ponniyamma.R   100.0  11.25               5380
# 4           12        SABAPATHI   100.0   0.00               5280
# ..         ...              ...     ...    ...                ...
# 88          30    praveen raj j    24.0   0.00               2380
# 89          31       AMARNATH D    -1.0  12.00               1890
# 90          32             bala    32.0   0.00               1720
# 91          33             XY Z    -1.0  -1.00                  0
# 92          34        Hariharan    -1.0  -1.00                  0
#
#     CodeKata Score                                 Department  Rising  \
# 0             5860  Electronics and Communication Engineering       0
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
#Average of previous week geekions
df['Previous Geekions'].mean()
# Out:
# 3842.3529411764707

# %%
#Average of this week geekions
df['CodeKata Score'].mean()
# Out:
# 4051.764705882353

# %% [markdown]
# ###### No of students participated

# %%
df['Name'].count()
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
[df['python'].mean(),
df['mysql'].mean(),
df['python_en'].mean(),
df['computational_thinking'].mean()]
# Out:
# [54.35294117647059, 23.5, 29.65714285714286, 2.2]

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df.sort_values("Rising", axis = 0, ascending = False).head(3)
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8            shifak N    58.0    0.0               5180            8320
# 18     Narasimhan Y L    -1.0    0.0               4800            6800
# 2   Ganesh Ramkumar R    -1.0   24.0               8790           10790
#
#                                 Department  Rising  python_en  \
# 8   Electronics and Electrical Engineering    3140        0.0
# 18        Computer Science and Engineering    2000       -1.0
# 2         Computer Science and Engineering    2000       55.0
#
#     computational_thinking
# 8                      0.0
# 18                     0.0
# 2                      6.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df.sort_values("Previous Geekions", axis = 0, ascending = False).head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
dept=df.pivot_table(index = 'Department', values='CodeKata Score')
dept.plot(kind='pie',y='CodeKata Score',autopct='%1.0f%%')

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
#cse topper
cs=(df['Department']=='Computer Science and Engineering')
cse= df[cs]

cse1= cse.sort_values(['Previous Geekions','python','mysql','CodeKata Score','computational_thinking'], ascending = False).head(1)
cse1
# Out:
#         Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0  A.Dharani    82.0   20.0              24500           24500
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN

# %%
#ece topper
ec=(df['Department']=='Electronics and Communication Engineering')
ece= df[ec]

ece1= ece.sort_values(['Previous Geekions','python','mysql','CodeKata Score','computational_thinking'], ascending = False).head(1)
ece1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3  Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                   Department  Rising  python_en  \
# 3  Electronics and Communication Engineering       0        0.0
#
#    computational_thinking
# 3                    -1.0

# %%
ee=(df['Department']=='Electronics and Electrical Engineering')
eee= df[ee]

eee1= eee.sort_values(['Previous Geekions','python','mysql','CodeKata Score','computational_thinking'], ascending = False).head(1)
eee1
# Out:
#             Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                Department  Rising  python_en  \
# 0  Electronics and Electrical Engineering       0        0.0
#
#    computational_thinking
# 0                     9.0

# %%
#concatenated['Department'].unique()
dept_details = df[["Department","CodeKata Score"]]
a = dept_details.groupby('Department')['CodeKata Score'].max()
a = a.to_frame()
a.rename(columns={'CodeKata Score': 'CodeKata_Score'}, inplace=True)
new = pd.DataFrame([a.index, a.CodeKata_Score ]).transpose()
new
# Out:
#                                            0      1
# 0           Computer Science and Engineering  24500
# 1  Electronics and Communication Engineering  10040
# 2     Electronics and Electrical Engineering  19400

# %%
#combining three department topper data
frames=[cse1,ece1,eee1]
topperList= pd.concat(frames)
#plotting them on chart
topperList.plot.barh(x='Name',title='Department wise toppers')
